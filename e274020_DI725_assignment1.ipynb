# %% [markdown]
# <a href="https://colab.research.google.com/github/aleynakirmizi/DI_725_Assignment_1/blob/main/e274020_DI725_assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Required Libraries**

# %% [markdown]
# "github deneme"

# %%
import pandas as pd

# %%
import os
from google.colab import userdata

# !git config --global user.email "aleykirmizi@gmail.com"
# !git config --global user.name "aleynakirmizi"

# !echo "# DI_725_Assignment_1" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main

# !git remote rm origin || true

github_token = userdata.get('GITHUB_TOKEN')

if github_token:
    # !git remote add origin https://{github_token}@github.com/aleynakirmizi/DI_725_Assignment_1.git
    # !git push -u origin main
else:
    print("Error: GitHub Personal Access Token (GITHUB_TOKEN) not found in Colab secrets.")
    print("Please follow the instructions above to create a PAT and add it to Colab secrets.")
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main c8ae237] first commit
#  1 file changed, 1 insertion(+)
# error: No such remote: 'origin'
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (15/15), 1.07 KiB | 1.07 MiB/s, done.
# Total 15 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/aleynakirmizi/DI_725_Assignment_1.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %% [markdown]
# ### 1. Check Git Status

# %%
# This command shows the status of changes as untracked, modified, or staged.
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### 2. Add All Changes (including the notebook)

# %%
# Adds all new and modified files in the current directory to the staging area.
# This will include your .ipynb file if it's new or has changes since the last commit.
# !git add .

# %% [markdown]
# ### 3. Commit Changes

# %%
# Commits the staged changes to your local repository with a descriptive message.
# Feel free to change the commit message to reflect your work.
# !git commit -m "Update: Add current Colab notebook and other changes"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### 4. Push to GitHub

# %%
# Pushes your committed changes from your local 'main' branch to the 'main' branch on GitHub.
# A 'git pull origin main' might be necessary first if there are conflicts from the remote.
# !git push origin main
# Out:
# Everything up-to-date
